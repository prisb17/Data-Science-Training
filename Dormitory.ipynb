# %%
import pandas as pd
dormitory= pd.read_csv('D:/respaldo/Data Science Northumbria/python_Northumbria/dormitory.csv')
print(dormitory.shape)
print(dormitory)
# Out:
# (1141, 15)
#                       Name         CreatedBy            CreatedOn  \
# 0     Access Card Reader-1       info@mma.ie  2017-07-26T09:12:43
# 1     Access Card Reader-2       info@mma.ie  2017-07-26T09:12:43
# 2     Access Card Reader-3       info@mma.ie  2017-07-26T09:12:43
# 3     Access Card Reader-4       info@mma.ie  2017-07-26T09:12:43
# 4     Access Card Reader-5       info@mma.ie  2017-07-26T09:12:43
# ...                    ...               ...                  ...
# 1136    WD:T04_W109_202104  mail@metz.uk.com  2017-07-02T06:24:42
# 1137    WD:T04_W110_202140  mail@metz.uk.com  2017-07-02T06:24:42
# 1138     WD:T05_114_189580  mail@metz.uk.com  2017-07-02T06:24:42
# 1139    WD:T05_W120_212483  mail@metz.uk.com  2017-07-02T06:24:42
# 1140    WD:T07_W132_971700  mail@metz.uk.com  2017-07-02T06:24:42
#
#                 TypeName    Space                            Description  \
# 0     Access Card Reader      128           Access Card Reader: Standard
# ...

# %%
# Create a new dataset derived from an existing dataset
# In this way, a data can be filtered by a characteristic which in this case is having the class 'Iris-setosa'
Ligthing_Fixture= dormitory[dormitory['ExternalObject']=='Lighting Fixtures']
print(Ligthing_Fixture)
# Out:
#                                         Name    CreatedBy  \
# 18     Ceiling Light - Linear Box 300x1200_1  info@mma.ie
# 19    Ceiling Light - Linear Box 300x1200_10  info@mma.ie
# 20    Ceiling Light - Linear Box 300x1200_11  info@mma.ie
# 21    Ceiling Light - Linear Box 300x1200_12  info@mma.ie
# 22    Ceiling Light - Linear Box 300x1200_13  info@mma.ie
# ...                                      ...          ...
# 1047              Table Lamp - Hemispheric_5  info@mma.ie
# 1048              Table Lamp - Hemispheric_6  info@mma.ie
# 1049              Table Lamp - Hemispheric_7  info@mma.ie
# 1050              Table Lamp - Hemispheric_8  info@mma.ie
# 1051              Table Lamp - Hemispheric_9  info@mma.ie
#
#                 CreatedOn                             TypeName Space  \
# 18    2017-07-25T10:15:16  Ceiling Light - Linear Box 300x1200   110
# 19    2017-07-25T10:15:16  Ceiling Light - Linear Box 300x1200   114
# ...

# %%
Ligthing_Fixture_unique=set(Ligthing_Fixture['TypeName'])
len(Ligthing_Fixture_unique)
print(Ligthing_Fixture_unique)
# Out:
# {'Coffer Light - Parabolic Square', 'MQ:T12', 'MQ:T13', 'Pendant Light - Linear - 2 Lamp', 'CeilingLight-RoundEmergencyA', 'MQ:T09', 'CeilingLight-RoundEmergencyB', 'Ceiling Light - Linear Box emergency light 300x1200mm 1Lamp 230 v', 'Table Lamp - Hemispheric', 'Ceiling Light - Linear Box 300x1200'} 10

# %%
Ligthing_Fixture_unique=list(set(Ligthing_Fixture['TypeName']))
frequency_Ligthing_Fixture_unique={}
for item in Ligthing_Fixture_unique:
    frequency[item]=Ligthing_Fixture.count(item)
print(frequency)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 'Coffer Light - Parabolic Square'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-18e897c512d2> in <module>
#       2 frequency_Ligthing_Fixture_unique={}
#       3 for item in Ligthing_Fixture_unique:
# ----> 4     frequency[item]=Ligthing_Fixture.count(item)
#       5 print(frequency)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    8703         Myla      1
#    8704         """
# ...
